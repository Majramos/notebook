# %% [markdown]
# # Wave Function Manipulation

# %%
import numpy as np
from bokeh.plotting import figure, show, output_notebook

output_notebook()
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="bf3cff1f-fd75-45c0-b952-a9e113d8b928">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ## Generate a simple sine wave

# %% [markdown]
# ### Using period as inputs with fixed freq

# %%
periods = 5
res = 1000 # resolution

x = np.linspace(0, periods*np.pi*2, res)
y = np.sin(x)

x2 = np.linspace(0, 6*np.pi*2, res)
y2 = np.sin(x2)

fig = figure(sizing_mode='stretch_width', height=300)
fig.line(x2, y2, legend_label='6 periods', color='orange')
fig.line(x, y, legend_label='5 periods')
fig.grid.visible = False
show(fig)
# Out:
#   <div id="eb5c3b80-d70c-4608-815a-8ab3491ebaa8" data-root-id="p1001" style="display: contents;"></div>

# %% [markdown]
# ### Using freq a input

# %%
freq = 1
Fs = 1000 # sample rate - no of samples per second
T = 1/Fs  # sampling period   %sample per second
t = 5     # seconds of sampling
N = Fs*t  # total points in signal

# signal information
omega = 2*np.pi*freq # angular frequency for sine waves
t_vec = np.arange(N)*T # time 
y3 = np.sin(omega*t_vec) # sine wave generation

fig = figure(sizing_mode='stretch_width', height=300)
fig.line(t_vec, y3)
fig.grid.visible = False
show(fig)
# Out:
#   <div id="b9d4abbe-517d-4a6d-a5c7-2f522bd48dc6" data-root-id="p1192" style="display: contents;"></div>
